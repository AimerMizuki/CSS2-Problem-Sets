# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup # now we get beautiful soup
import requests # need this to talk to a website

# %%
url = 'https://en.wikipedia.org/wiki/MonsterVerse'
response = requests.get(url)
response.status_code
soup= BeautifulSoup(response.content,'html.parser')

# %%
df = pd.read_html(url)
df = df[3]
df.columns =['Character','Godzilla','Kong:SkullIsland','Godzilla:King of the Monsters', 'Godzilla vs. Kong']
df =df.set_index('Character')

#this should work for fast the furrious too!
for i in range(len(df)) :
  list = []
  for j in range(len(df.columns)):
    list.append(df.iloc[i,j])

  if all(ele == list[0] for ele in list):
    df = df.drop(df.index[i])
    break

df.head(7)
# Out:
#                              Godzilla  ... Godzilla vs. Kong
# Character                              ...
# Godzilla                  T.J. StormS  ...               CGI
# MUTO             Matt CrossSLee RossS  ...   Archive footage
# King Kong                         NaN  ...   Eric PeteyS[57]
# King Ghidorah                     NaN  ...   Archive footage
# Rodan                             NaN  ...   Archive footage
# Ishiro Serizawa          Ken Watanabe  ...               NaN
# Vivienne Graham         Sally Hawkins  ...               NaN
#
# [7 rows x 4 columns]

# %%
df.to_csv('new_monster_data.csv',sep=' ')

pd.read_csv('new_monster_data.csv')
# Out:
#    Character Godzilla Kong:SkullIsland "Godzilla:King of the Monsters" "Godzilla vs. Kong"
# 0   Godzilla "T.J. StormS" "Pictured with archive ...
# 1   MUTO "Matt CrossSLee RossS"  CGI "Archive foot...
# 2   King Kong  "Terry NotarySToby KebbellS" "Archi...
# 3   King Ghidorah  Pictured "Jason LilesSAlan Maxs...
# 4    Rodan  Pictured "Jason LilesS" "Archive footage"
# 5     Ishiro Serizawa "Ken Watanabe"  "Ken Watanabe"
# 6   Vivienne Graham "Sally Hawkins"  "Sally Hawkins"
# 7   William Stentz "David Strathairn"  "David Stra...
# 8       Ford Brody "Aaron Taylor-JohnsonCJ AdamsY"
# 9                     Elle Brody "Elizabeth Olsen"
# 10                      Joe Brody "Bryan Cranston"
# 11                 Sandra Brody "Juliette Binoche"
# 12      Houston Brooks  "Corey Hawkins" "Joe Morton"
# 13  William Randa  "John Goodman"  "Pictured with ...
# 14                   James Conrad  "Tom Hiddleston"
# 15      Hank Marlow  "John C. ReillyWill BrittainY"
# ...
